# %% [markdown]
# <a href="https://colab.research.google.com/github/kessanchit2-cmd/Ml-Pracs/blob/main/Linearregression1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linear regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#load csv
df=pd.read_csv('/content/final_dataset.csv')
print(df)
# Out:
#       Unnamed: 0  beds  baths    size  zip_code      price
# 0              0     3    2.5  2590.0     98144   795000.0
# 1              1     4    2.0  2240.0     98106   915000.0
# 2              2     4    3.0  2040.0     98107   950000.0
# 3              3     4    3.0  3800.0     98199  1950000.0
# 4              4     2    2.0  1042.0     98102   950000.0
# ...          ...   ...    ...     ...       ...        ...
# 2011        2011     3    2.0  1370.0     98112   910000.0
# 2012        2012     1    1.0   889.0     98121   550000.0
# 2013        2013     4    2.0  2140.0     98199  1150000.0
# 2014        2014     2    2.0   795.0     98103   590000.0
# 2015        2015     3    2.0  1710.0     98133   659000.0
#
# [2016 rows x 6 columns]

# %%
#feature Selection
x=df[['size']]
y=df['price']

# %%
#train model
X_train, X_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction
y_pred=model.predict(X_test)
print(y_pred)
# Out:
# [1016683.34292356 1229295.16307777 1247237.08882917  581143.09530808
#   910825.98099024  512515.22930894  874942.12948742 1955943.15600987
#   638557.25771259 1000535.60974729  504441.3627208  1090245.23850434
#   810799.74492613  534045.54021063  955680.79536876  904097.75883346
#  1440112.79065683  502198.62200188  825601.83367104 1244545.79996646
#   717950.27916258 1298371.57722069  700008.35341117  683412.07209112
#   735892.20491399 1076788.79419078  839058.2779846   630483.39112446
#  1188925.83013709  534045.54021063 1354888.64333763 1498424.04934891
#   543913.59937391  969137.23968232  897369.53667668  357317.57155924
#  1108187.16425575 1489453.08647321  534942.6364982   901855.01811453
#   874942.12948742  455998.163192    547501.98452419  767290.57497896
#  1807922.26856073 1018477.5354987   577554.7101578   480219.7629564
#   404863.67480048  924282.4253038   823359.09295212  482911.05181911
#  1092487.97922326 1027448.4983744  1009506.57262299  919796.94386594
# ...

# %%
#metrics
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean Squared Error:",mse)
print("R-squared:",r2)
# Out:
# Mean Squared Error: 154013700255.702
# R-squared: 0.5330001415076608

# %%
#accuracy, precision , recall
accuracy=r2
precision=r2
recall=r2
print("Accuracy:",accuracy)
print("Precision:",precision)
print("Recall:",recall)
# Out:
# Accuracy: 0.5330001415076608
# Precision: 0.5330001415076608
# Recall: 0.5330001415076608

# %%
#plot
plt.figure(figsize=(8,5))
plt.scatter(X_test,y_test,color='blue',label='Actual')
plt.plot(X_test,y_pred,color='red',label='Predicted',linewidth=2)
plt.xlabel('Size')
plt.ylabel('Price')
plt.title('Linear Regression')
plt.legend()
plt.show()
