# %% [markdown]
# <a href="https://colab.research.google.com/github/kessanchit2-cmd/Ml-Pracs/blob/main/Numby%2CPandas%2CSciPy%2CSkitLearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Numby
import numpy as np
#create an array
a=np.array([1,2,3,4,5,7])
print('Array')
print(a)

#mathematical operations
print("Mean",np.mean(a))
print("Sum",np.sum(a))
print("Median",np.median(a))
print("Standard Deviation",np.std(a))
print("Variance",np.var(a))
# Out:
# Array
# [1 2 3 4 5 7]
# Mean 3.6666666666666665
# Sum 22
# Median 3.5
# Standard Deviation 1.9720265943665387
# Variance 3.8888888888888893

# %%
#pandas
import pandas as pd
#create DataFrames
data={
    'Names':['Alice','Bob','Charlie','David'],
    'Ages':[25,30,35,40],
    'City':['New York','San Francisco','Los Angeles','Chicago']

}
df=pd.DataFrame(data)
print(df)
#display Information
print(df.head())
print(df.info())
print(df.describe())
# Out:
#      Names  Ages           City
# 0    Alice    25       New York
# 1      Bob    30  San Francisco
# 2  Charlie    35    Los Angeles
# 3    David    40        Chicago
#      Names  Ages           City
# 0    Alice    25       New York
# 1      Bob    30  San Francisco
# 2  Charlie    35    Los Angeles
# 3    David    40        Chicago
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Names   4 non-null      object
#  1   Ages    4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
# None
#             Ages
# count   4.000000
# mean   32.500000
# std     6.454972
# min    25.000000
# 25%    28.750000
# 50%    32.500000
# 75%    36.250000
# max    40.000000

# %%
#Scipy
from scipy import stats

data = [10,20,30,40,50]
# Mean
print("Mean:", stats.tmean(data))
# Median
print("Median:", stats.scoreatpercentile(data, 50))
# Out:
# Mean: 30.0
# Median: 30.0

# %%
#Matplotlib
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [10,20,25,30,40]
plt.plot(x, y)
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
#SkitLearn
from sklearn.linear_model import LinearRegression
import numpy as np

# Training Data
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])

# Model
model = LinearRegression()

# Train
model.fit(X, y)

# Prediction
pred = model.predict([[6]])

print("Prediction:", pred)
# Out:
# Prediction: [12.]
